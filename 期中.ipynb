# %% [markdown]
# <a href="https://colab.research.google.com/github/YueCyuan/big-data/blob/master/%E6%9C%9F%E4%B8%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#安裝套件
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)
library(ggplot2)

# %%
df <-data.frame(gp = factor(rep(letters[1:3],each = 10)),y=rnorm(30))
ggplot(df,aes(x=gp,y=y))+geom_point()
#X=gp Y=y的點狀圖
# Out:
# plot without title

# %%
ggplot(df, aes(x = gp, y = y)) +geom_boxplot()
#X=gp Y=y的盒狀圖
# Out:
# plot without title

# %%
df$z<-df$y+rnorm(30) #定義Z和Y
ggplot(df, aes(x = z, y = y)) +geom_point()+facet_grid(gp~.)
#X=Z Y=y的點狀圖
# Out:
# plot without title

# %%
ggplot(df, aes(x = z, y = y)) +geom_point()+facet_grid(gp~.)+geom_smooth()
#X=z Y=y的點狀圖加趨勢線
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(df, aes(x = z, y = y)) +geom_line()+facet_grid(gp~.)
#X=z Y=y的折線圖
# Out:
# plot without title

# %%
df<-data.frame(	Blocks=factor(rep(letters[1:3], each = 10)),GamesPlayed = rnorm(30))
ggplot(df , aes(x= 	Blocks, y= GamesPlayed))+geom_point()
#x=Block y=GamesPlayed
# Out:
# plot without title

# %%
ggplot(df, aes(x = 	Blocks, y = GamesPlayed)) +geom_boxplot()
#x=Block y=GamesPlayed
# Out:
# plot without title

# %%
# Out:
# Error in eval_tidy(mapping$x, data, caller_env): object 'NBA1516' not found
# Traceback:
#
# 1. qplot(GamesPlayed, data = NBA1516, fill = Position)
# 2. eval_tidy(mapping$x, data, caller_env)

# %%
#按照個人失誤由大到小排列

NBA1516Order<-NBA1516[order(NBA1516$PersonalFouls,decreasing=T),]
NBA1516Order[1:30,]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 19  NBA    Gi Antetokounmpo MIL  SF       80          2825
# 357 NBA    Mason Plumlee    POR  PF       82          2087
# 194 NBA    Roy Hibbert      LAL  C        81          1881
# 122 NBA    Andre Drummond   DET  C        81          2664
# 431 NBA    Karl-antho Towns MIN  C        82          2621
# 368 NBA    Julius Randle    LAL  PF       81          2287
# 167 NBA    Draymond Green   GSW  SF       81          2807
# 307 NBA    Paul Millsap     ATL  PF       81          2640
# 98  NBA    Demarcus Cousins SAC  C        65          2245
# 36  NBA    Matt Barnes      MEM  SF       76          2190
# 47  NBA    Patrick Beverley HOU  PG       71          2038
# 99  NBA    Robert Covington PHI  SF       67          1902
# 154 NBA    Paul George      IND  SF       81          2828
# 263 NBA    Alex Len         PHO  C        78          1820
# 178 NBA    James Harden     HOU  SG       82          3121
# ...

# %%
#湖人隊的子集
subset(NBA1516,Team=="LAL")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 25  NBA    Ron Artest       LAL  SF       35           588
# 38  NBA    Brandon Bass     LAL  PF       66          1342
# 50  NBA    Tarik Black      LAL  C        39           495
# 64  NBA    Anthony Brown    LAL  SF       29           596
# 67  NBA    Kobe Bryant      LAL  SG       66          1861
# 90  NBA    Jordan Clarkson  LAL  PG       79          2556
# 194 NBA    Roy Hibbert      LAL  C        81          1881
# 210 NBA    Marcelo Huertas  LAL  PG       53           866
# 249 NBA    Ryan Kelly       LAL  PF       36           469
# 323 NBA    Larryjr Nance    LAL  PF       63          1268
# 368 NBA    Julius Randle    LAL  PF       81          2287
# 386 NBA    D'angelo Russell LAL  PG       80          2257
# 387 NBA    Robert Sacre     LAL  C        25           320
# 462 NBA    Louis Williams   LAL  SG       67          1911
# 473 NBA    Nick Young       LAL  SF       54          1036
# ...

# %%
#找出Anthony
NBA1516[grepl("Anthony",NBA1516$Name),]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 21  NBA    Carmelo Anthony  NYK  SF       72          2529
# 22  NBA    Joel Anthony     DET  C        19            95
# 46  NBA    Anthony Bennett  TOR  PF       19            85
# 64  NBA    Anthony Brown    LAL  SF       29           596
# 108 NBA    Anthony Davis    NOR  PF       61          2159
# 316 NBA    Anthony Morrow   OKL  SG       68           930
# 429 NBA    Anthony Tolliver DET  PF       72          1338
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 21  567            1307                105        310             ⋯ 62
# 22    6              10                  0          0             ⋯  2
# 46    8              26                  3         14             ⋯  5
# 64   39             126                 20         70             ⋯ 14
# 108 560            1137                 35        108             ⋯ 78
# ...
